# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from tqdm.auto import tqdm
import seaborn as sns
import statsmodels.api as sm
sns.set()

# %% [markdown]
# Data Analysis

# %%
res = pd.read_csv('res.csv')

# %%
n_to_plot=100000
njump=int(len(res)/n_to_plot)

# %%
# %matplotlib notebook
plt.scatter(res['SW'].iloc[::njump],res['phie'].iloc[::njump],c=res['GR'].iloc[::njump],marker=".",s=1)
plt.xlabel('Saturação de Água (%)')
plt.ylabel('Porosidade Efetiva (%)')
plt.colorbar(label='Raio Gama (gAPI)')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(res['GR'].iloc[::njump],res['SW'].iloc[::njump],res['phie'].iloc[::njump],s=1,c=res['GR'].iloc[::njump],zdir='z',depthshade=True)
cbar = fig.colorbar(p)
cbar.set_label('Raio Gama (gAPI)')
ax.view_init(40, -120)
ax.set_ylabel('Saturação de Água (%)')
ax.set_zlabel('Porosidade Efetiva (%)')
ax.set_xlabel('Raio Gama (gAPI)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# PCA

# %%
from sklearn.cluster import *
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
features=res[['SW','phie','GR','RHOB','ILD','X','Y','Z']]
data0=preprocessing.scale(features)

# %%
pca = PCA(n_components=3)
pcs = pca.fit_transform(data0).T
print(np.sum(pca.explained_variance_ratio_),pca.explained_variance_ratio_)
# Out:
# 0.6456331882291739 [0.27651991 0.22450171 0.14461157]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(pcs[0][::njump],pcs[1][::njump],pcs[2][::njump],c=pcs[0][::njump],zdir='z',depthshade=True,s=1)
cbar = fig.colorbar(p)
cbar.set_label('PC3')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.view_init(45, 5)
plt.show()

# %% [markdown]
# N-Clusters

# %%
def get_wcss(data,maxk=15):
    wcss=[]
    for k in tqdm(range(1,maxk)):
        kmeans = KMeans(k,init='k-means++')
        kmeans.fit_predict(data)
        wcss.append(kmeans.inertia_)
    return wcss

# %%
wcss_data = get_wcss(data0)
wcss_pca = get_wcss(pcs.T)
# Out:
# HBox(children=(IntProgress(value=0, max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=14), HTML(value='')))

# %%
ss=wcss_pca
ss2=wcss_data
delta=[]
delta2=[]
krange=range(1,len(ss)-1)
for i in krange:
    delta.append((ss[i-1]-ss[i]))
    delta2.append((ss2[i-1]-ss2[i]))
    
plt.subplot(1,2,1)
plt.plot(krange,delta)
plt.scatter(krange,delta)
plt.xticks(krange)
plt.xlabel('Núm. Clusters PCA')
plt.ylabel('WCSS')
plt.subplot(1,2,2)
plt.plot(krange,delta2)
plt.scatter(krange,delta2)
plt.xlabel('Núm. Clusters sem PCA')
plt.xticks(krange)
# Out:
# ([<matplotlib.axis.XTick at 0x23607a73cc0>,
#   <matplotlib.axis.XTick at 0x23607a73550>,
#   <matplotlib.axis.XTick at 0x23607a67780>,
#   <matplotlib.axis.XTick at 0x23607aa54e0>,
#   <matplotlib.axis.XTick at 0x23607aa59b0>,
#   <matplotlib.axis.XTick at 0x23607aa5e80>,
#   <matplotlib.axis.XTick at 0x23607aac390>,
#   <matplotlib.axis.XTick at 0x23607aac860>,
#   <matplotlib.axis.XTick at 0x23607aacd30>,
#   <matplotlib.axis.XTick at 0x23607ab2278>,
#   <matplotlib.axis.XTick at 0x23607ab2710>,
#   <matplotlib.axis.XTick at 0x23607ab2be0>],
#  <a list of 12 Text xticklabel objects>)

# %% [markdown]
# K-Means

# %%
kmeans = KMeans(5,init='k-means++')
new_data = res.copy()
new_data['Cluster0']=kmeans.fit_predict(pcs.T)
clusters0=new_data['Cluster0']

# %%
for i in new_data['Cluster0'].unique():
    print(i, len(new_data.loc[new_data['Cluster0'] == i]))
# Out:
# 2 80668
# 3 122497
# 0 75778
# 1 98679
# 4 90597

# %%
plt.scatter(res['SW'].iloc[::njump],res['phie'].iloc[::njump],c=new_data['Cluster0'].iloc[::njump],s=1,marker='.',cmap='magma')
plt.xlabel('Reservoir Water Saturation')
plt.ylabel('Reservoir Effective Porosity')
plt.colorbar(ticks=[0,1,2,3,4],spacing='uniform',label='Classes')
plt.show()

# %%
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter(new_data['Cluster0'].iloc[::njump],res['SW'].iloc[::njump],res['phie'].iloc[::njump],s=1,c=new_data['Cluster0'].iloc[::njump],zdir='z',depthshade=True)
cbar = fig.colorbar(p)
cbar.set_label('Raio Gama (gAPI)')
ax.view_init(40, -10)
ax.set_ylabel('Saturação de Água (%)')
ax.set_zlabel('Porosidade Efetiva (%)')
ax.set_xlabel('Raio Gama (gAPI)')
plt.show()

# %%
# %matplotlib inline
j_slice=int((np.max(new_data['j']))/2)
j_slice_data=new_data.loc[new_data['j'] == j_slice]
xplot = j_slice_data['i']
yplot = j_slice_data['k']
plt.figure(figsize=(12,3))
plt.scatter(xplot,yplot,c=j_slice_data['Cluster0'],marker='.',cmap='magma')
plt.colorbar(ticks=[0,1,2,3,4],spacing='uniform',label='Classes')
plt.ylabel('K célula - Profundidade')
plt.xlabel('J célula - Inlines')
# Out:
# Text(0.5, 0, 'J célula - Inlines')

# %%
i_slice=int((np.max(new_data['i']))/2)
i_slice_data=new_data.loc[new_data['i'] == i_slice]
xplot = i_slice_data['j']
yplot = i_slice_data['k']
plt.figure(figsize=(4,3))
plt.scatter(xplot,yplot,c=i_slice_data['Cluster0'],cmap='magma')
plt.colorbar(ticks=[0,1,2,3,4],label='Classes')
plt.ylabel('K célula - Profundidade')
plt.xlabel('I célula - Crosslines')
# Out:
# Text(0.5, 0, 'I célula - Crosslines')

# %%
k_slice=int((np.median(new_data['k']))/1)
k_slice_data=new_data.loc[new_data['k'] == k_slice]
xplot = k_slice_data['X']
yplot = k_slice_data['Y']
plt.scatter(xplot,yplot,c=k_slice_data['Cluster0'],marker='.',cmap='magma')
plt.colorbar(ticks=[0,1,2,3,4],spacing='uniform',label='Classes')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
# Out:
# Text(0.5, 0, 'Longitude')

# %%
new_data.to_csv('cluster.csv')
